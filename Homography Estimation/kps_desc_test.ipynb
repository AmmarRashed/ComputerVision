# %%
from utils import *
from extra import *

# %matplotlib inline
# Out:
# OpenCV version: 3.4.2

# %% [markdown]
# ### Reading images

# %%
# kpd = KeypointDetector("data/bikes/img1.ppm")
kpd = KeypointDetector("chess.jpg")

# %% [markdown]
# ## Keypoints detectors

# %%
dst_harris = harris(kpd.gray)
annotate_keypoints(kpd.img, dst_harris,show=True)

# %% [markdown]
# ### Shi-Tomasi

# %%
dst_shi = shi_tomasi(kpd.gray)
annotate_keypoints(kpd.img, dst_shi, show=True)

# %% [markdown]
# ### FAST

# %%
kp_fast = kpd.fast()
kpd.draw_kp(kp_fast)
# Out:
# Threshold:  10
# nonmaxSuppression:  True
# neighborhood:  2
# Total Keypoints with nonmaxSuppression:  368

# %% [markdown]
# ### Star

# %%
kp_star = kpd.star()
kpd.draw_kp(kp_star)

# %%
kps = kps_union([kp_fast, kp_star])

# %% [markdown]
# ## Descriptors
# ### SIFT

# %%
kp_sift, desc_sift = kpd.describe("sift", kps)
kpd.draw_kp(kp_sift)
# Out:
# Keypoints count: 419

# %% [markdown]
# ### SURF

# %%
kp_surf, desc_surf = kpd.describe("surf", kps)
# kpd.draw_kp(kp_surf)
# Out:
# Keypoints count: 419

# %%
matcher = cv2.BFMatcher()
matches = matcher.match(desc_surf,desc_surf)

# %%
m.distance

# %% [markdown]
# ### BRIEF

# %%
kp_star, desc_brief = kpd.describe("brief", kps)
# kpd.draw_kp(kp_star)

# %% [markdown]
# ### ORB

# %%
kp_orb, desc_orb = kpd.describe("orb", kps)
# kpd.draw_kp(kp_orb)

# %% [markdown]
# ### Match the descriptors from two images and estimate the homography matrix from the matched key points
